# %% [markdown]
# # Филиппова Анна НПМбд-01-20
# # Задание 5.2
# ## Exercise 1
# 1. Создайте график $x^2⋅sin(1/x^2)+x$ на интервале $[−1,1]$, используя 250 точек. Не забудьте пометить оси!
# 2. Создайте semilogy график (с логарифмической шкалой для оси y и линейной шкалой для оси x) относительной разницы  функций $1/(1+x^2)$ и $1/x^2$ на интервале $[5,25]$. (Относительная разница чисел $a$ и $b$ определяется как $|1−a/b|$)
# 3. В Scipy также есть много менее распространенных специальных функций. Взгляните на обширный список <a href=https://docs.scipy.org/doc/scipy/reference/special.html> здесь</a>! Выберите несколько интересных спец функций, которые вы знаете (или, может быть, не знаете), подставьте несколько чисел и начертите их.

# %% [markdown]
# ## Exercise 2
# 1. Построить график функции $sin(x)/x$ на отрезке $[-6\pi;6\pi]$ и добавить тики по оси $x$ с шагом $\pi/2$ от $-6\pi$ до $6\pi$, причём обозначения тиков должны содержать греческую букву $\pi$. Добавить сетку на график.

# %% [markdown]
# ## Exercise 3
# 1. Создайте цветовой график $sin(x)sin(y)$ на интервале $[−π,π]×[−π,π]$.
# 2. Создайте цветовой график $e^{-x^2-y^2}$ на интервале $[−3,3]×[−3,3]$.

# %% [markdown]
# ## Задание 1

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from scipy import special

# %%
x = np.linspace(-1.0, 1.0, 250)
y = x ** 2 * np.sin(1 / x ** 2) + x
plt.plot(x, y)
plt.xlabel(u'Ось x', family='verdana')
plt.ylabel(u'Ось y', family='verdana')
plt.title('График 1.1')
# Out:
# Text(0.5, 1.0, 'График 1.1')

# %%
x = np.linspace(5, 25, 100)
y = 1 - ((1 / (1 + x ** 2)) / (1 / x ** 2))
plt.semilogy(x, y)
plt.xlabel(u'Ось x', family='verdana')
plt.ylabel(u'Ось y', family='verdana')
plt.title('График 1.2')
# Out:
# Text(0.5, 1.0, 'График 1.2')

# %%
x = np.linspace(-2, 2, 150) 
plt.plot(x, scipy.special.dawsn(x),color = 'gold', label='Интеграл Доусона') 
plt.plot(x, scipy.special.cbrt(x), color = 'peru', label='Поэлементный кубический корень из x' ) 
plt.plot(x, scipy.special.ndtr(x), color = 'skyblue', label='Функция кумулятивного распределения по Гауссу')
plt.xlabel(u'Ось x', family='verdana')
plt.ylabel(u'Ось y', family='verdana')
plt.title('График 1.3')
plt.legend()

# %% [markdown]
# ## Задание 2

# %%
x = np.linspace(-6*np.pi, 6*np.pi, 250)
y = np.sin(x) / x
plt.figure(figsize=(15, 5))
plt.plot(x, y)
points = np.arange(-6 * np.pi, 6.001 * np.pi, np.pi / 2)
plt.xticks(points, list(map(lambda x: x + "π", map(str, np.arange(-6, 6.001, 0.5)))))
plt.xlabel(u'Ось x', family='verdana')
plt.ylabel(u'Ось y', family='verdana')
plt.title('График 2')
plt.grid()

# %% [markdown]
# ## Задание 3

# %%
x = np.linspace(-np.pi, np.pi, 250)
y = np.linspace(-np.pi, np.pi, 250)
X,Y = np.meshgrid(x,y)

Z = np.sin(X) * np.sin(Y)
fig, ax = plt.subplots(figsize=(6,5))
norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax.pcolor(X, Y, Z, norm = norm, cmap="ocean")
ax.axis('tight')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))

cb = fig.colorbar(p, ax=ax)
cb.set_ticks([-1, -.5, 0, .5, 1])
plt.title('График 3.1')
# Out:
# Text(0.5, 1.0, 'График 3.1')

# %%
x = np.linspace(-3, 3, 250)
y = np.linspace(-3, 3, 250)
X,Y = np.meshgrid(x,y)

Z = np.exp(-X**2 - Y**2)
fig, ax = plt.subplots(figsize=(6,5))
norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax.pcolor(X, Y, Z, norm = norm, cmap="Set2")
ax.axis('tight')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))

cb = fig.colorbar(p, ax=ax)
cb.set_ticks([-1, -.5, 0, .5, 1])
plt.title('График 3.2')
# Out:
# Text(0.5, 1.0, 'График 3.2')
